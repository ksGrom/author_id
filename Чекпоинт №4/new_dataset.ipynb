# %% [markdown]
# ## Описание статистик ruTS
#
# Источник: https://github.com/SergeyShk/ruTS/tree/ead346d33840b11f6898b4d9329abdd370334572
#
# ### Основные метрики
# * число предложений (n_sents)
# * число слов (n_words)
# * число уникальных слов (n_unique_words)
# * число длинных слов
# * число сложных слов
# * число простых слов
# и т.д.
#
#
#
# ### Метрики читаемости
#
# * **тест Флеша-Кинкайда (flesch_kincaid_grade)**
# Чем выше показатель, тем сложнее текст для чтения
# Результатом является число лет обучения в американской системе образования, необходимых для понимания текста
# return (a * n_words / n_sents) + (b * n_syllables / n_words) - c
#
# * **индекс удобочитаемости Флеша (flesch_reading_easy)**
# Чем выше показатель, тем легче текст для чтения
# Значения индекса лежат в пределах от 0 до 100 и могут интерпретироваться следующим образом:
#             100-90 - 5-й класс
#             90-80 - 6-й класс
#             80-70 - 7-й класс
#             70-60 - 8-й и 9-й класс
#             60-50 - 10-й и 11-й класс
#             50-30 - Студент университета
#             30-0 - Выпускник университета
#
# * **индекс Колман-Лиау (coleman_liau_index)**
# Чем выше показатель, тем сложнее текст для чтения
# Результатом является число лет обучения в американской системе образования, необходимых для понимания текста
# return (a * n_letters / n_words * 100) - (b * n_sents / n_words * 100) - c
#
# * **индекс SMOG (smog_index)**
# Simple Measure of Gobbledygook («Простое измерение разглагольствований»)
# Наиболее авторитетная метрика читабельности
# Чем выше показатель, тем сложнее текст для чтения
# Результатом является число лет обучения в американской системе образования, необходимых для понимания текста
#
# * **автоматический индекс удобочитаемости (automated_readability_index)**
# Чем выше показатель, тем сложнее текст для чтения
# Результатом является число лет обучения в американской системе образования, необходимых для понимания текста
# Значения индекса могут интерпретироваться следующим образом:
#             1 - 6-7 лет
#             2 - 7-8 лет
#             3 - 8-9 лет
#             4 - 9-10 лет
#             5 - 10-11 лет
#             6 - 11-12 лет
#             7 - 12-13 лет
#             8 - 13-14 лет
#             9 - 14-15 лет
#             10 - 15-16 лет
#             11 - 16-17 лет
#             12 - 17-18 лет
#
# * **индекс удобочитаемости LIX (lix)**
# Чем выше показатель, тем сложнее текст для чтения
# Значения индекса лежат в пределах от 0 до 100 и могут интерпретироваться следующим образом:
# 0-30 - Очень простые тексты, детская литература
# 30-40 - Простые тексты, художественная литература, газетные статьи
# 40-50 - Тексты средней сложности, журнальные статьи
# 50-60 - Сложные тексты, научно-популярные статьи, профессиональная литература, официальные тексты
# 60-100 - Очень сложные тексты, написанные канцелярским языком, законы
#
# ### Морфологические статистики
# * **gender:** neut, masc, femn, none
# * **tense:** pres, past, futr, none
# * **voice:** pssv, actv, none
# * **person:** 2, 3, 1, none

# %%
# !pip uninstall numpy
# !pip install numpy==1.22
# Out:
# Found existing installation: numpy 1.24.0
# Uninstalling numpy-1.24.0:
#   Would remove:
#     /usr/local/bin/f2py
#     /usr/local/bin/f2py3
#     /usr/local/bin/f2py3.8
#     /usr/local/lib/python3.8/dist-packages/numpy-1.24.0.dist-info/*
#     /usr/local/lib/python3.8/dist-packages/numpy.libs/libgfortran-040039e1.so.5.0.0
#     /usr/local/lib/python3.8/dist-packages/numpy.libs/libopenblas64_p-r0-15028c96.3.21.so
#     /usr/local/lib/python3.8/dist-packages/numpy.libs/libquadmath-96973f99.so.0.0.0
#     /usr/local/lib/python3.8/dist-packages/numpy/*
# Proceed (y/n)? y
#   Successfully uninstalled numpy-1.24.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting numpy==1.22
#   Using cached numpy-1.22.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ruts 0.8.1 requires numpy<2.0.0,>=1.23.0, but you have numpy 1.22.0 which is incompatible.
# Successfully installed numpy-1.22.0

# %%
# !pip install h5py
# !pip install typing-extensions
# !pip install wheel
import pandas as pd
import numpy as np
import matplotlib

# !pip install wordcloud

from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

# !pip install ruts

import re
#from nltk.corpus import stopwords
#from ruts import SentsExtractor, WordsExtractor

#import nltk
#nltk.download('stopwords')

from ruts import BasicStats
from ruts import ReadabilityStats
from ruts import DiversityStats
from ruts import MorphStats


import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import colorsys

import os
from tqdm import tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/lib/python3.8/dist-packages (from h5py) (1.24.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (4.4.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wheel in /usr/local/lib/python3.8/dist-packages (0.38.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.8/dist-packages (1.8.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from wordcloud) (3.6.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from wordcloud) (7.1.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.8/dist-packages (from wordcloud) (1.24.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->wordcloud) (1.0.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ruts in /usr/local/lib/python3.8/dist-packages (0.8.1)
# Requirement already satisfied: nltk<4.0,>=3.7 in /usr/local/lib/python3.8/dist-packages (from ruts) (3.7)
# Requirement already satisfied: pandas<2.0.0,>=1.4.3 in /usr/local/lib/python3.8/dist-packages (from ruts) (1.5.2)
# Requirement already satisfied: graphviz<0.21.0,>=0.20.1 in /usr/local/lib/python3.8/dist-packages (from ruts) (0.20.1)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from ruts) (1.9.3)
# Requirement already satisfied: matplotlib<4.0.0,>=3.3.0 in /usr/local/lib/python3.8/dist-packages (from ruts) (3.6.2)
# Requirement already satisfied: spacy<4.0.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from ruts) (3.4.4)
# Requirement already satisfied: pymorphy2<0.10.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from ruts) (0.9.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /usr/local/lib/python3.8/dist-packages (from ruts) (1.24.0)
# Requirement already satisfied: razdel<0.6.0,>=0.5.0 in /usr/local/lib/python3.8/dist-packages (from ruts) (0.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4.0.0,>=3.3.0->ruts) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4.0.0,>=3.3.0->ruts) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4.0.0,>=3.3.0->ruts) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4.0.0,>=3.3.0->ruts) (7.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4.0.0,>=3.3.0->ruts) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4.0.0,>=3.3.0->ruts) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4.0.0,>=3.3.0->ruts) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4.0.0,>=3.3.0->ruts) (0.11.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk<4.0,>=3.7->ruts) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk<4.0,>=3.7->ruts) (1.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk<4.0,>=3.7->ruts) (4.64.1)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk<4.0,>=3.7->ruts) (7.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.4.3->ruts) (2022.6)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /usr/local/lib/python3.8/dist-packages (from pymorphy2<0.10.0,>=0.9.1->ruts) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.8/dist-packages (from pymorphy2<0.10.0,>=0.9.1->ruts) (0.6.2)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.8/dist-packages (from pymorphy2<0.10.0,>=0.9.1->ruts) (0.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.3.0->ruts) (1.15.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (1.0.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (1.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (8.1.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (2.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (2.23.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (2.4.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (1.10.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (3.0.10)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (6.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (0.7.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (57.4.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (0.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<4.0.0,>=3.4.0->ruts) (2.11.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<4.0.0,>=3.4.0->ruts) (4.4.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->ruts) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->ruts) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->ruts) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->ruts) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<4.0.0,>=3.4.0->ruts) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<4.0.0,>=3.4.0->ruts) (0.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<4.0.0,>=3.4.0->ruts) (2.0.1)
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
train = pd.read_csv('https://raw.githubusercontent.com/anyakazachkova/project/main/%D0%A7%D0%B5%D0%BA%D0%BF%D0%BE%D0%B8%D0%BD%D1%82%20%E2%84%964/datasets/TRAIN_500words_lemmatized.csv?token=GHSAT0AAAAAAB2L7SLJE3L6DCOJO3N6IKYEY5D5NJA')
test = pd.read_csv('https://raw.githubusercontent.com/anyakazachkova/project/main/%D0%A7%D0%B5%D0%BA%D0%BF%D0%BE%D0%B8%D0%BD%D1%82%20%E2%84%964/datasets/TEST_500words_lemmatized.csv?token=GHSAT0AAAAAAB2L7SLIAVKELNLDWQ6GMLEMY5D5N5Q')

# %%
print(train.shape)
print(test.shape)
# Out:
# (9758, 6)
# (2033, 6)

# %%
train.head()
# Out:
#           author author_surname               work_title  excerpt_num  \
# 0  anton-chekhov          Чехов  antreprener-pod-divanom            0
# 1  anton-chekhov          Чехов                   anyuta            0
# 2  anton-chekhov          Чехов                   anyuta            1
# 3  anton-chekhov          Чехов               aptekarsha            0
# 4  anton-chekhov          Чехов               aptekarsha            1
#
#                                                 text  \
# 0  Антрепренёр под диваном \n (Закулисная история...
# 1  Анюта \n В самом дешевом номерке меблированных...
# 2  Несомненно, будущее прекрасно, и из Клочкова, ...
# 3  Аптекарша \n Городишко Б., состоящий из двух-т...
# 4  Входят толстяк-доктор и тонкий Обтесов. Теперь...
#
#                                               lemmas
# 0  антрепренёр диван закулисный история идти воде...
# 1  анюта сам дешёвый номерок меблированный комнат...
# 2  несомненно будущее прекрасно клочков вероятно ...
# 3  аптекарша городишко б состоять два три кривая ...
# 4  входить толстяк доктор тонкий обтесовый рассмо...

# %%
train['text'][0].strip().replace('\n', '')
# Out:
    bs_data = dict(bs.get_stats())
    del bs_data['c_letters']
    del bs_data['c_syllables']

  
    # метрики читаемости
    rs = ReadabilityStats(chapter_text)
    rs_data = dict(rs.get_stats())


    # морфологические метрики
    ms = MorphStats(chapter_text)
    ms_data = dict(ms.get_stats())


    # метрики лексического разнообразия
    ds = DiversityStats(chapter_text)
    ds_data = dict(ds.get_stats())

    d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]] = {**bs_data, **rs_data, **ms_data['gender'], **ms_data['number'], **ms_data['tense'], **ms_data['voice'], **ms_data['person'], **ds_data}
    df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)

    books.append(str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id])
    authors.append(train['author'][part_id])
    df.index = books
    df['author'] = authors
    df.to_csv('TRAIN_500words_lemmatized_metrics.csv')
  except:
      pass
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|█████▉    | 1866/3115 [31:40<22:41,  1.09s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|█████▉    | 1867/3115 [31:41<21:39,  1.04s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|█████▉    | 1868/3115 [31:41<19:47,  1.05it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1869/3115 [31:42<18:40,  1.11it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1870/3115 [31:43<16:57,  1.22it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1871/3115 [31:44<18:33,  1.12it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1872/3115 [31:45<17:37,  1.17it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1873/3115 [31:45<16:58,  1.22it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1874/3115 [31:46<15:48,  1.31it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1875/3115 [31:47<15:10,  1.36it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1876/3115 [31:47<14:42,  1.40it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1877/3115 [31:48<15:27,  1.33it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1878/3115 [31:49<16:31,  1.25it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1879/3115 [31:50<16:20,  1.26it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1880/3115 [31:51<16:56,  1.22it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1881/3115 [31:52<17:09,  1.20it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1882/3115 [31:53<17:55,  1.15it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1883/3115 [31:53<17:44,  1.16it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  60%|██████    | 1884/3115 [31:55<20:56,  1.02s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1885/3115 [31:56<21:52,  1.07s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1886/3115 [31:57<22:52,  1.12s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1887/3115 [31:58<20:19,  1.01it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1888/3115 [31:59<20:21,  1.00it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1889/3115 [32:00<21:15,  1.04s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1890/3115 [32:01<20:18,  1.01it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1891/3115 [32:02<21:09,  1.04s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1892/3115 [32:03<20:33,  1.01s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1893/3115 [32:04<21:21,  1.05s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1894/3115 [32:05<20:05,  1.01it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1895/3115 [32:06<20:56,  1.03s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1896/3115 [32:07<20:45,  1.02s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1897/3115 [32:08<21:13,  1.05s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1898/3115 [32:09<18:52,  1.07it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1899/3115 [32:10<18:10,  1.11it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1900/3115 [32:10<16:44,  1.21it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1901/3115 [32:11<17:25,  1.16it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1902/3115 [32:13<19:17,  1.05it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1903/3115 [32:13<18:27,  1.09it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1904/3115 [32:14<18:52,  1.07it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1905/3115 [32:15<20:11,  1.00s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1906/3115 [32:16<19:06,  1.05it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████    | 1907/3115 [32:17<18:36,  1.08it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████▏   | 1908/3115 [32:18<18:20,  1.10it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████▏   | 1909/3115 [32:19<17:28,  1.15it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████▏   | 1910/3115 [32:20<16:45,  1.20it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████▏   | 1911/3115 [32:21<18:40,  1.07it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████▏   | 1912/3115 [32:22<19:11,  1.04it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████▏   | 1913/3115 [32:23<19:09,  1.05it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████▏   | 1914/3115 [32:23<17:04,  1.17it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  61%|██████▏   | 1915/3115 [32:24<16:56,  1.18it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1916/3115 [32:25<17:29,  1.14it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1917/3115 [32:26<17:07,  1.17it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1918/3115 [32:27<16:09,  1.23it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1919/3115 [32:28<17:28,  1.14it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1920/3115 [32:28<17:15,  1.15it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1921/3115 [32:29<17:20,  1.15it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1922/3115 [32:30<16:13,  1.23it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1923/3115 [32:31<16:12,  1.23it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1924/3115 [32:32<18:35,  1.07it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1925/3115 [32:33<17:23,  1.14it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1926/3115 [32:34<16:27,  1.20it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1927/3115 [32:34<16:21,  1.21it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1928/3115 [32:35<15:49,  1.25it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1929/3115 [32:36<15:13,  1.30it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1930/3115 [32:37<14:51,  1.33it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1931/3115 [32:37<14:44,  1.34it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1932/3115 [32:38<14:10,  1.39it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1933/3115 [32:39<16:25,  1.20it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1934/3115 [32:40<18:31,  1.06it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1935/3115 [32:41<17:17,  1.14it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1936/3115 [32:42<18:31,  1.06it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1937/3115 [32:43<18:09,  1.08it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1938/3115 [32:44<19:21,  1.01it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1939/3115 [32:45<18:20,  1.07it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1940/3115 [32:46<17:42,  1.11it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1941/3115 [32:46<15:42,  1.25it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1942/3115 [32:47<15:42,  1.24it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1943/3115 [32:48<16:03,  1.22it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1944/3115 [32:49<17:48,  1.10it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1945/3115 [32:50<16:52,  1.16it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  62%|██████▏   | 1946/3115 [32:51<16:22,  1.19it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  63%|██████▎   | 1947/3115 [32:51<16:39,  1.17it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  63%|██████▎   | 1948/3115 [32:53<18:29,  1.05it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  63%|██████▎   | 1949/3115 [32:54<19:19,  1.01it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  63%|██████▎   | 1950/3115 [32:55<19:44,  1.02s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  63%|██████▎   | 1951/3115 [32:57<25:18,  1.30s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  63%|██████▎   | 1952/3115 [32:58<22:29,  1.16s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  63%|██████▎   | 1953/3115 [32:58<20:44,  1.07s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  63%|██████▎   | 1954/3115 [32:59<19:06,  1.01it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  63%|██████▎   | 1955/3115 [33:00<17:45,  1.09it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  63%|██████▎   | 1956/3115 [33:01<16:44,  1.15it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  63%|██████▎   | 1957/3115 [33:02<16:27,  1.17it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  63%|██████▎   | 1958/3115 [33:03<17:02,  1.13it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  63%|██████▎   | 1959/3115 [33:03<15:54,  1.21it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  63%|██████▎   | 1960/3115 [33:04<15:59,  1.20it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  63%|██████▎   | 1961/3115 [33:05<17:40,  1.09it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3084/3115 [51:06<00:35,  1.13s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3085/3115 [51:07<00:33,  1.13s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3086/3115 [51:08<00:29,  1.02s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3087/3115 [51:09<00:25,  1.10it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3088/3115 [51:10<00:24,  1.08it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3089/3115 [51:11<00:27,  1.06s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3090/3115 [51:12<00:24,  1.00it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3091/3115 [51:13<00:24,  1.02s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3092/3115 [51:14<00:21,  1.05it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3093/3115 [51:15<00:22,  1.04s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3094/3115 [51:16<00:19,  1.08it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3095/3115 [51:17<00:17,  1.14it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3096/3115 [51:17<00:15,  1.24it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3097/3115 [51:18<00:13,  1.34it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3098/3115 [51:19<00:14,  1.15it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
#  99%|█████████▉| 3099/3115 [51:20<00:14,  1.10it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|█████████▉| 3100/3115 [51:21<00:13,  1.11it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|█████████▉| 3101/3115 [51:21<00:11,  1.20it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|█████████▉| 3102/3115 [51:23<00:13,  1.01s/it]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|█████████▉| 3103/3115 [51:24<00:11,  1.05it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|█████████▉| 3104/3115 [51:25<00:10,  1.09it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|█████████▉| 3105/3115 [51:25<00:09,  1.10it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|█████████▉| 3106/3115 [51:26<00:08,  1.10it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|█████████▉| 3107/3115 [51:27<00:06,  1.15it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|█████████▉| 3108/3115 [51:28<00:05,  1.18it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|█████████▉| 3109/3115 [51:29<00:04,  1.20it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|█████████▉| 3110/3115 [51:30<00:04,  1.17it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|█████████▉| 3111/3115 [51:30<00:03,  1.21it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|█████████▉| 3112/3115 [51:31<00:02,  1.21it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|█████████▉| 3113/3115 [51:32<00:01,  1.18it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|█████████▉| 3114/3115 [51:33<00:00,  1.18it/s]<ipython-input-10-10e3821be425>:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(d[str(part_id) + ' ' + train['author'][part_id] + ' ' + train['work_title'][part_id]], ignore_index=True)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# 100%|██████████| 3115/3115 [51:34<00:00,  1.01it/s]

# %%
# расчеты для теста

books = []
authors = []



df = pd.DataFrame()
d = {}

for part_id in tqdm(range(len(test['text']))):
  chapter_text = test['text'][part_id].strip().replace('\n', '')

  try:
    # добавляем базовые статистики
    bs = BasicStats(chapter_text)
    bs_data = dict(bs.get_stats())
    del bs_data['c_letters']
    del bs_data['c_syllables']

  
    # метрики читаемости
    rs = ReadabilityStats(chapter_text)
    rs_data = dict(rs.get_stats())


    # морфологические метрики
    ms = MorphStats(chapter_text)
    ms_data = dict(ms.get_stats())


    # метрики лексического разнообразия
    ds = DiversityStats(chapter_text)
    ds_data = dict(ds.get_stats())

    d[str(part_id) + ' ' + test['author'][part_id] + ' ' + test['work_title'][part_id